# %%
import pyspark
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.window import Window

conf = pyspark.SparkConf()
spark = SparkSession.builder.config(conf=conf).getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/11/05 11:46:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
### some basic cleaning, exploration, and QA

store_open_close = spark.read.csv('system2_case_study_transaction_data_location_info.csv', header=True, inferSchema=True)
store_sales = spark.read.csv('system2_case_study_transaction_data_monthly_sales_by_locationid.csv', header=True, inferSchema=True)
store_info = spark.read.csv('system2_case_study_webscrape_data_locations.csv', header=True, inferSchema=True)
comp_sales = spark.read.csv('system2_case_study_reported_numbers.csv', header=True, inferSchema=True)

# there are dupes in the store_open_close table
# assuming that we can grab the min and max dates (for this assignment)
store_open_close = store_open_close.groupBy('locationid').agg(F.min(F.col('est_open_date')).alias('est_open_date'),F.max(F.col('est_close_date')).alias('est_close_date'))

# there are dupes in the sales table
# assuming that we can add them together (for this assignment)
store_sales = store_sales.groupBy('locationid','period_start','period_end','label').agg(F.sum(F.col('amount')).alias('amount'))
store_sales = store_sales.withColumn('qt_end', F.date_sub(F.add_months(F.date_trunc('quarter', F.col('period_end')), 3), 1))
store_sales.show()
# Out:
# [Stage 8:>                                                          (0 + 1) / 1]
# +----------+------------+----------+---------+------------------+----------+
# |locationid|period_start|period_end|    label|            amount|    qt_end|
# +----------+------------+----------+---------+------------------+----------+
# |      1041|  2019-08-01|2019-08-31|2019-MS08|1337.5012817107845|2019-09-30|
# |      1080|  2019-08-01|2019-08-31|2019-MS08|202.40023576342875|2019-09-30|
# |       331|  2019-08-01|2019-08-31|2019-MS08| 3784.071590671761|2019-09-30|
# |       336|  2019-08-01|2019-08-31|2019-MS08|1168.5250390091855|2019-09-30|
# |       474|  2019-08-01|2019-08-31|2019-MS08| 1611.716807033345|2019-09-30|
# |       583|  2019-08-01|2019-08-31|2019-MS08| 771.0859404306472|2019-09-30|
# |       651|  2019-08-01|2019-08-31|2019-MS08| 3446.550485547101|2019-09-30|
# |       754|  2019-08-01|2019-08-31|2019-MS08| 5494.037670844849|2019-09-30|
# |       902|  2019-08-01|2019-08-31|2019-MS08| 2908.162819356863|2019-09-30|
# |       125|  2019-09-01|2019-09-30|2019-MS09|161.34738341932922|2019-09-30|
# |       364|  2019-09-01|2019-09-30|2019-MS09|1289.7475733152774|2019-09-30|
# |       223|  2019-09-01|2019-09-30|2019-MS09| 2239.085580660844|2019-09-30|
# |      1150|  2019-11-01|2019-11-30|2019-MS11| 660.1077024805525|2019-12-31|
# |       422|  2019-11-01|2019-11-30|2019-MS11| 885.7381864165151|2019-12-31|
# |       555|  2019-11-01|2019-11-30|2019-MS11| 629.5618326302445|2019-12-31|
# |       621|  2019-11-01|2019-11-30|2019-MS11| 308.6462627817611|2019-12-31|
# |      1401|  2019-12-01|2019-12-31|2019-MS12|244.12840872765165|2019-12-31|
# |      5513|  2019-12-01|2019-12-31|2019-MS12|1650.6074638125235|2019-12-31|
# |      4139|  2020-01-01|2020-01-31|2020-MS01| 529.1747849036633|2020-03-31|
# |      4140|  2020-01-01|2020-01-31|2020-MS01| 659.7738580636641|2020-03-31|
# +----------+------------+----------+---------+------------------+----------+
# only showing top 20 rows

# %%
# comp sales
comp_sales.show()
# Out:
# +------+--------------------+-------------+------------+
# |entity|              metric|period_end_dt|reported_yoy|
# +------+--------------------+-------------+------------+
# |  PRTY|Brand Comparable ...|      3/31/16|      -1.50%|
# |  PRTY|Brand Comparable ...|      6/30/16|       3.80%|
# |  PRTY|Brand Comparable ...|      9/30/16|       1.20%|
# |  PRTY|Brand Comparable ...|     12/31/16|      -3.50%|
# |  PRTY|Brand Comparable ...|      3/31/17|       1.70%|
# |  PRTY|Brand Comparable ...|      6/30/17|       0.10%|
# |  PRTY|Brand Comparable ...|      9/30/17|      -2.60%|
# |  PRTY|Brand Comparable ...|     12/31/17|      -1.40%|
# |  PRTY|Brand Comparable ...|      3/31/18|       2.40%|
# |  PRTY|Brand Comparable ...|      6/30/18|       0.10%|
# |  PRTY|Brand Comparable ...|      9/30/18|      -1.00%|
# |  PRTY|Brand Comparable ...|     12/31/18|      -2.90%|
# |  PRTY|Brand Comparable ...|      3/31/19|      -1.40%|
# |  PRTY|Brand Comparable ...|      6/30/19|      -2.10%|
# |  PRTY|Brand Comparable ...|      9/30/19|      -2.60%|
# |  PRTY|Brand Comparable ...|     12/31/19|      -5.10%|
# |  PRTY|Brand Comparable ...|      3/31/20|     -17.10%|
# |  PRTY|Brand Comparable ...|      6/30/20|     -52.40%|
# |  PRTY|Brand Comparable ...|      9/30/20|       8.30%|
# |  PRTY|Brand Comparable ...|     12/31/20|      -5.90%|
# +------+--------------------+-------------+------------+
# only showing top 20 rows

# %%
# top stores by dollar amount after pandemic
store_sales.where(F.col('period_start') >= '2020-08-01').groupBy('locationid').agg(F.sum('amount').alias('amount')).orderBy(F.col('amount').desc()).show()
# Out:
# +----------+------------------+
# |locationid|            amount|
# +----------+------------------+
# |       410|1810943.4764412066|
# |       520| 650131.7460584699|
# |       846| 592398.1937818673|
# |       117|  542125.375890249|
# |       761| 535687.6311212053|
# |       754|464942.72885827586|
# |       634| 460643.3228629713|
# |       710| 443666.2680222966|
# |       103| 399132.0899436094|
# |       118|387569.39450555603|
# |       109| 367129.8510906332|
# |       534|353681.77233843994|
# |       413| 349595.9001168511|
# |       411| 349474.4484120353|
# |      5999| 327721.3119189659|
# |       320| 318470.6679776114|
# |      1441| 312759.7299203606|
# |         3| 305194.6331005389|
# |       514| 299039.7201772194|
# |       601| 298525.9638211416|
# +----------+------------------+
# only showing top 20 rows

# %%
# stores that did not join to a web location
store_sales_agg = store_sales.where(F.col('period_start') >= '2022-01-01').groupBy('locationid').agg(F.sum(F.col('amount')).alias('amount'))

store_sales_agg.select('locationid', 'amount').distinct().join(store_info.withColumn('locationid', F.col('location_id')), 'locationid', 'left').where(F.col('store_services').isNull()).orderBy(F.col('amount').desc()).show(50)
# Out:
# +----------+------------------+-------+----------+----+-----+-----+-----------+--------------+-----+----+-------+--------+--------+---------+
# |locationid|            amount|address|as_of_date|city|phone|state|location_id|store_services|title| url|zipcode|postcode|latitude|longitude|
# +----------+------------------+-------+----------+----+-----+-----+-----------+--------------+-----+----+-------+--------+--------+---------+
# |      5999| 327721.3119189659|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      1441| 312759.7299203606|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       110|183206.33633870876|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       606| 167599.8570311895|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       607|166764.71929308082|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       634|161723.44203367725|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      3060|131081.08353832853|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      3850|130204.91791774618|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      2620| 129957.3536307503|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       534|109952.80890639062|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      2485|108240.73466011173|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      2011| 98738.58521697485|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       545| 93273.09474435738|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       109| 86215.98962384606|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      1047| 83526.96374914363|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       517|  80541.4573585515|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       402| 75870.44675493964|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       107| 73081.25369690744|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      2500| 70574.08762835895|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      3353| 69766.31613538507|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       106| 68068.83785390838|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       604| 67528.82173158528|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       888|64342.394204599594|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       916| 63976.40103261611|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       524| 59600.19661596833|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       515|58179.269504914846|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       533| 53207.16029007712|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       526| 50427.09684819768|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      2935| 50276.51429456317|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       172| 47604.49005561243|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       602| 45786.61307975868|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      4575| 42865.45631728023|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |        36| 41560.14844143945|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      4410|40826.744944356884|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       662| 40063.62024077477|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       528| 39152.54022049982|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       151| 37272.80401567391|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      2825| 34835.59034679448|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |        17| 34686.45413381914|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      5191| 34625.18682217922|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       400| 34427.54924833165|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      1500| 33560.76162064156|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       865| 32566.61800668917|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       229|32545.752243105893|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       599| 32462.97022262454|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       516| 31184.23678931085|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |      6044|30202.707061657347|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |        28|29890.011247287966|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |       982|  29867.2669768132|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# |        18|29756.870985386882|   NULL|      NULL|NULL| NULL| NULL|       NULL|          NULL| NULL|NULL|   NULL|    NULL|    NULL|     NULL|
# +----------+------------------+-------+----------+----+-----+-----+-----------+--------------+-----+----+-------+--------+--------+---------+
# only showing top 50 rows

# %%
# web location that did not join to sales
store_info.withColumn('locationid', F.col('location_id')) .join(store_sales.select('locationid').distinct(), 'locationid', 'anti').select('location_id','state', 'store_services').show(200, truncate = False)
# Out:
# +-----------+--------------+-----------------------------------------------------------------------------------------------------------------------------------------------+
# |location_id|state         |store_services                                                                                                                                 |
# +-----------+--------------+-----------------------------------------------------------------------------------------------------------------------------------------------+
# |1138       |Minnesota     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1115       |Missouri      |In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                  |
# |1020       |New Jersey    |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |1160       |Arkansas      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |633        |Louisiana     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1186       |Virginia      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1131       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1224       |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1230       |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1030       |North Carolina|Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |1122       |Virginia      |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |1193       |Washington    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1197       |Tennessee     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1195       |Tennessee     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1165       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1159       |Ohio          |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |321        |Arkansas      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Helium                                                                                 |
# |1239       |California    |In-Store Shopping | In-Store Pickup | Helium                                                                                                   |
# |1233       |Florida       |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1156       |Alabama       |In-Store Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                                                                   |
# |1032       |North Carolina|Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |1125       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1143       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1147       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1187       |Virginia      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1029       |Virginia      |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |49         |Puerto Rico   |In-Store Shopping | In-Store Pickup | Helium                                                                                                   |
# |1226       |Pennsylvania  |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |5291       |Tennessee     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1199       |Arizona       |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |6060       |Massachusetts |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |138        |Puerto Rico   |In-Store Shopping | In-Store Pickup | Helium                                                                                                   |
# |1240       |California    |In-Store Shopping | In-Store Pickup | Helium                                                                                                   |
# |1516       |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |707        |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1142       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1169       |Virginia      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |6072       |New Hampshire |In-Store Shopping | In-Store Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                                               |
# |1073       |Oklahoma      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1118       |Oregon        |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1194       |Tennessee     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1225       |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1223       |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |689        |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1135       |Minnesota     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1140       |Minnesota     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1243       |California    |In-Store Shopping | In-Store Pickup                                                                                                            |
# |470        |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |141        |Puerto Rico   |In-Store Shopping | In-Store Pickup | Helium                                                                                                   |
# |1244       |South Carolina|In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1129       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |687        |New York      |In-Store Shopping | In-Store Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                                               |
# |1027       |North Carolina|Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |5139       |Illinois      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |5187       |Nebraska      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |6047       |New Hampshire |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1015       |Delaware      |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |1151       |Minnesota     |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |1519       |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |441        |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |614        |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1242       |California    |In-Store Shopping | In-Store Pickup | Helium                                                                                                   |
# |622        |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |507        |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |425        |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1026       |North Carolina|Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |1231       |Florida       |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1192       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1168       |Virginia      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |253        |Puerto Rico   |In-Store Shopping | In-Store Pickup | Helium                                                                                                   |
# |1144       |North Dakota  |In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                  |
# |1235       |Missouri      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |6026       |Massachusetts |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1146       |North Dakota  |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |674        |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1232       |Florida       |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery                                      |
# |1134       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1158       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1198       |South Carolina|In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1196       |Tennessee     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1126       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1145       |North Dakota  |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1191       |North Dakota  |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1149       |Minnesota     |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |1141       |Minnesota     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1109       |Missouri      |In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                  |
# |5205       |Missouri      |In-Store Shopping | Helium                                                                                                                     |
# |269        |Arkansas      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Helium                                                                                 |
# |1167       |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |5334       |Iowa          |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1202       |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1228       |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1227       |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1133       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1189       |Virginia      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |167        |Puerto Rico   |In-Store Shopping | In-Store Pickup | Helium                                                                                                   |
# |1075       |Oklahoma      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1111       |Texas         |In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                  |
# |1028       |North Carolina|Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |5260       |Missouri      |In-Store Shopping | Helium                                                                                                                     |
# |5231       |Missouri      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |809        |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1163       |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1241       |California    |In-Store Shopping | In-Store Pickup | Helium                                                                                                   |
# |876        |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |965        |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |968        |California    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |6022       |Massachusetts |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1221       |New York      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1113       |Texas         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1188       |Virginia      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |1011       |Tennessee     |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |1237       |Georgia       |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |
# |5189       |Nebraska      |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|
# |1119       |Missouri      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Delivery | Helium Inflation | Balloon Delivery                                         |
# +-----------+--------------+-----------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# web location that did not join to sales by state 

(
store_info
 .withColumn('locationid', F.col('location_id'))
    .join(store_sales.select('locationid').distinct(), 'locationid', 'anti')
    .groupBy('state')
    .agg(
        F.count_distinct('location_id').alias('store_ct')
    )
 .show(50, truncate = False)
)
# Out:
# +--------------+--------+
# |state         |store_ct|
# +--------------+--------+
# |Minnesota     |6       |
# |Ohio          |1       |
# |Oregon        |1       |
# |Arkansas      |3       |
# |Texas         |14      |
# |North Dakota  |4       |
# |Pennsylvania  |1       |
# |Nebraska      |2       |
# |Puerto Rico   |5       |
# |Washington    |1       |
# |Illinois      |1       |
# |Oklahoma      |2       |
# |Delaware      |1       |
# |Missouri      |7       |
# |Georgia       |1       |
# |Virginia      |8       |
# |North Carolina|5       |
# |New Jersey    |1       |
# |Alabama       |1       |
# |Arizona       |1       |
# |Iowa          |1       |
# |Massachusetts |3       |
# |Louisiana     |1       |
# |Tennessee     |6       |
# |New Hampshire |2       |
# |Florida       |3       |
# |South Carolina|2       |
# |California    |19      |
# |New York      |12      |
# +--------------+--------+

# %%
# worst performing new york 2022 yoy

store_sales_agg = (
    store_sales
    .where(F.col('period_start') >= '2021-01-01')
    .groupBy('locationid')
    .agg(
        F.sum(F.when((F.col('period_start') >= '2021-01-01') 
               & (F.col('period_start') < '2022-01-01'), F.col('amount') ).otherwise(0)).alias('2021_spend'),
        F.sum(F.when((F.col('period_start') >= '2022-01-01') 
               & (F.col('period_start') < '2023-01-01'), F.col('amount') ).otherwise(0)).alias('2022_spend')
    
    )
    .withColumn('yoy',F.round((F.col('2022_spend') - F.col('2021_spend'))/F.col('2021_spend'), 4))

)

(
store_info
 .withColumn('locationid', F.col('location_id'))
 .join(store_sales_agg, 'locationid', 'inner')
    .orderBy(F.col('yoy'))
.select('state', 'city', 'yoy')
    .where(F.col('state') == 'New York' )
 .show(10, truncate = False)
)
# Out:
# +--------+-------------+-------+
# |state   |city         |yoy    |
# +--------+-------------+-------+
# |New York|Brooklyn     |-0.5073|
# |New York|Brooklyn     |-0.4267|
# |New York|Schenectady  |-0.4041|
# |New York|Bronx        |-0.3777|
# |New York|Staten Island|-0.3517|
# |New York|Patchogue    |-0.3448|
# |New York|Bronx        |-0.3423|
# |New York|Brooklyn     |-0.3408|
# |New York|Rosedale     |-0.327 |
# |New York|New Hartford |-0.2781|
# +--------+-------------+-------+
# only showing top 10 rows

# %%
# worst performing every state 2022 yoy
store_sales_agg = (
    store_sales
    .where(F.col('period_start') >= '2021-01-01')
    .groupBy('locationid')
    .agg(
        F.sum(F.when((F.col('period_start') >= '2021-01-01') 
               & (F.col('period_start') < '2022-01-01'), F.col('amount') ).otherwise(0)).alias('2021_spend'),
        F.sum(F.when((F.col('period_start') >= '2022-01-01') 
               & (F.col('period_start') < '2023-01-01'), F.col('amount') ).otherwise(0)).alias('2022_spend')
    
    )
    .withColumn('2022_yoy_change',(F.round((F.col('2022_spend') - F.col('2021_spend'))/F.col('2021_spend'), 4)))

)

(
store_info
 .withColumn('locationid', F.col('location_id'))
 .join(store_sales_agg, 'locationid', 'inner')
    .orderBy(F.col('2022_yoy_change'))
.select('state', 'city', '2022_yoy_change')
    # .where(F.col('state') == 'California' )
 .show(50, truncate = False)
)
# Out:
# +------------+----------------+---------------+
# |state       |city            |2022_yoy_change|
# +------------+----------------+---------------+
# |Maryland    |Pasadena        |NULL           |
# |New Jersey  |South Plainfield|-0.7736        |
# |California  |Rialto          |-0.7357        |
# |California  |Indio           |-0.6306        |
# |Arkansas    |Little Rock     |-0.6078        |
# |California  |Santa Rosa      |-0.5997        |
# |California  |Lancaster       |-0.5941        |
# |Michigan    |Roseville       |-0.5903        |
# |Nevada      |Las Vegas       |-0.5879        |
# |California  |Riverside       |-0.5724        |
# |California  |Anaheim         |-0.5683        |
# |California  |Downey          |-0.5615        |
# |California  |Santa Clarita   |-0.5558        |
# |California  |West Covina     |-0.5545        |
# |Illinois    |Berwyn          |-0.5507        |
# |Texas       |Brownsville     |-0.5444        |
# |Illinois    |Chicago         |-0.5358        |
# |Texas       |Carrollton      |-0.533         |
# |Michigan    |Rochester Hills |-0.5283        |
# |Michigan    |Allen Pk        |-0.5241        |
# |Illinois    |Calumet City    |-0.5161        |
# |New York    |Brooklyn        |-0.5073        |
# |California  |San Dimas       |-0.5064        |
# |Texas       |Port Arthur     |-0.506         |
# |California  |West Los Angeles|-0.5024        |
# |California  |La Habra        |-0.4944        |
# |California  |Long Beach      |-0.4917        |
# |New Jersey  |Kenilworth      |-0.4909        |
# |New Jersey  |Delran          |-0.4876        |
# |Nevada      |Reno            |-0.4854        |
# |Indiana     |Columbus        |-0.4854        |
# |Hawaii      |Waipahu         |-0.4853        |
# |Colorado    |Denver          |-0.4848        |
# |Texas       |Round Rock      |-0.4794        |
# |Pennsylvania|Stroudsburg     |-0.4785        |
# |New Jersey  |Howell          |-0.4774        |
# |Illinois    |Rockford        |-0.4771        |
# |California  |Torrance        |-0.4657        |
# |Michigan    |Sterling Heights|-0.4657        |
# |New Jersey  |Sicklerville    |-0.4584        |
# |California  |Menifee         |-0.4565        |
# |New Jersey  |Clifton         |-0.4545        |
# |Illinois    |Chicago         |-0.4541        |
# |Hawaii      |Honolulu        |-0.4531        |
# |New Jersey  |North Bergen    |-0.4506        |
# |Indiana     |Merrillville    |-0.4451        |
# |Nevada      |Henderson       |-0.4406        |
# |New Jersey  |Mays Landing    |-0.4391        |
# |Illinois    |Chicago         |-0.4388        |
# |California  |Reseda          |-0.4325        |
# +------------+----------------+---------------+
# only showing top 50 rows

# %%
# worst performing states

store_sales_agg = (
    store_sales
    .where(F.col('period_start') >= '2021-01-01')


)

(
store_info
 .withColumn('locationid', F.col('location_id'))
 .join(store_sales_agg, 'locationid', 'inner')
    
    .groupBy('state')
    .agg(
        F.sum(F.when((F.col('period_start') >= '2021-01-01') 
               & (F.col('period_start') < '2022-01-01'), F.col('amount') ).otherwise(0)).alias('2021_spend'),
        F.sum(F.when((F.col('period_start') >= '2022-01-01') 
               & (F.col('period_start') < '2023-01-01'), F.col('amount') ).otherwise(0)).alias('2022_spend'),
        F.count_distinct('location_id').alias('store_ct')
    
    )
    .withColumn('2022_yoy_change',F.round((F.col('2022_spend') - F.col('2021_spend'))/F.col('2021_spend'), 4))
.select('state', '2022_yoy_change', 'store_ct')
    # .where(F.col('state') == 'California' )
    .orderBy(F.col('2022_yoy_change'))
 .show(50, truncate = False)
)
# Out:
# +--------------+---------------+--------+
# |state         |2022_yoy_change|store_ct|
# +--------------+---------------+--------+
# |Arkansas      |-0.6078        |1       |
# |Hawaii        |-0.4799        |2       |
# |New Jersey    |-0.3937        |25      |
# |Nevada        |-0.3837        |6       |
# |Michigan      |-0.3581        |21      |
# |California    |-0.2964        |69      |
# |Colorado      |-0.2011        |13      |
# |Illinois      |-0.1973        |38      |
# |Florida       |-0.1094        |60      |
# |Indiana       |-0.1025        |17      |
# |New Mexico    |-0.0926        |3       |
# |Rhode Island  |-0.066         |2       |
# |Georgia       |-0.0582        |26      |
# |Missouri      |-0.0476        |8       |
# |Kentucky      |-0.0399        |8       |
# |New Hampshire |-0.0192        |1       |
# |Virginia      |-0.0096        |13      |
# |New York      |0.0107         |37      |
# |Oregon        |0.0184         |1       |
# |Oklahoma      |0.0411         |5       |
# |Pennsylvania  |0.0413         |25      |
# |Ohio          |0.0661         |23      |
# |Texas         |0.0908         |68      |
# |South Carolina|0.0962         |8       |
# |Nebraska      |0.1003         |1       |
# |Alabama       |0.1958         |9       |
# |Minnesota     |0.2122         |4       |
# |Arizona       |0.2622         |14      |
# |Kansas        |0.2672         |4       |
# |North Carolina|0.2772         |16      |
# |Maryland      |0.3005         |20      |
# |Washington    |0.3077         |15      |
# |Connecticut   |0.3316         |11      |
# |Iowa          |0.3538         |5       |
# |Vermont       |0.3945         |1       |
# |West Virginia |0.4683         |1       |
# |Alaska        |0.4927         |1       |
# |Massachusetts |0.6224         |17      |
# |Tennessee     |0.7511         |10      |
# |Maine         |0.7812         |2       |
# |Louisiana     |1.0326         |6       |
# |Wisconsin     |1.2077         |11      |
# |Delaware      |1.3867         |1       |
# |Mississippi   |14.3175        |3       |
# +--------------+---------------+--------+

# %%
# worst performing group of servies

store_sales_agg = (
    store_sales
    .where(F.col('period_start') >= '2021-01-01')


)

(
store_info
 .withColumn('locationid', F.col('location_id'))
 .join(store_sales_agg, 'locationid', 'inner')
    
    .groupBy('store_services')
    .agg(
        F.sum(F.when((F.col('period_start') >= '2021-01-01') 
               & (F.col('period_start') < '2022-01-01'), F.col('amount') ).otherwise(0)).alias('2021_spend'),
        F.sum(F.when((F.col('period_start') >= '2022-01-01') 
               & (F.col('period_start') < '2023-01-01'), F.col('amount') ).otherwise(0)).alias('2022_spend'),
        F.count_distinct('location_id').alias('store_ct')
    
    )
    .withColumn('2022_yoy_change',F.round((F.col('2022_spend') - F.col('2021_spend'))/F.col('2021_spend'), 4))
.select('store_services', '2022_yoy_change', 'store_ct')
    # .where(F.col('state') == 'California' )
    .orderBy(F.col('2022_yoy_change'))
 .show(50, truncate = False)
)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------+--------------------+--------+
# |store_services                                                                                                                                 |2022_yoy_change     |store_ct|
# +-----------------------------------------------------------------------------------------------------------------------------------------------+--------------------+--------+
# |In-Store Shopping | Next Gen | Helium                                                                                                          |-0.5878762814390801 |1       |
# |In-Store Shopping                                                                                                                              |-0.43166200141841643|4       |
# |In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                  |-0.29231420655440815|7       |
# |In-Store Shopping | In-Store Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                                               |-0.2557209013359899 |10      |
# |In-Store Shopping | In-Store Pickup | Curbside Pickup | Helium                                                                                 |-0.22266848529408126|8       |
# |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Helium                                                    |-0.07069910967026245|1       |
# |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |-0.0469865370596831 |545     |
# |In-Store Shopping | In-Store Pickup | Curbside Pickup | Delivery | Helium Inflation | Balloon Delivery                                         |0.03431083035964323 |2       |
# |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|0.04131023962800896 |23      |
# |In-Store Shopping | Helium                                                                                                                     |0.08709859634525216 |27      |
# |In-Store Shopping | In-Store Pickup | Helium                                                                                                   |0.21444829815271754 |2       |
# |Flag Ship Store | In-Store Shopping | Next Gen | Helium                                                                                        |0.679176194158311   |1       |
# |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Helium                                                |16.933944281408696  |1       |
# +-----------------------------------------------------------------------------------------------------------------------------------------------+--------------------+--------+

# %%
# worst performing services in general

store_sales_agg = (
    store_sales
    .where(F.col('period_start') >= '2021-01-01')


)

for service in ['Flag Ship Store', 
                'In-Store Shopping', 
                'Next Gen', 
                'In-Store Pickup', 
                'Curbside Pickup', 
                'Scheduled or Same Day Delivery', 
                'Balloon Delivery', 'Helium']:
    (
    store_info
     .withColumn('locationid', F.col('location_id'))
     .join(store_sales_agg, 'locationid', 'inner')
        .withColumn('store_services', F.when(F.col('store_services').rlike(service), service).otherwise(f'No {service}'))
        .groupBy('store_services')
        .agg(
            F.sum(F.when((F.col('period_start') >= '2021-01-01') 
                   & (F.col('period_start') < '2022-01-01'), F.col('amount') ).otherwise(0)).alias('2021_spend'),
            F.sum(F.when((F.col('period_start') >= '2022-01-01') 
                   & (F.col('period_start') < '2023-01-01'), F.col('amount') ).otherwise(0)).alias('2022_spend'),
            F.count_distinct('location_id').alias('store_ct')
        
        )
        .withColumn('2022_yoy_change',F.round((F.col('2022_spend') - F.col('2021_spend'))/F.col('2021_spend'), 4))
    .select('store_services', '2022_yoy_change', 'store_ct')
        # .where(F.col('state') == 'California' )
        .orderBy(F.col('2022_yoy_change'))
     .show(50, truncate = False)
    )
# Out:
# +------------------+---------------+--------+
# |store_services    |2022_yoy_change|store_ct|
# +------------------+---------------+--------+
# |No Flag Ship Store|-0.0555        |607     |
# |Flag Ship Store   |0.0581         |25      |
# +------------------+---------------+--------+
#
# +-----------------+---------------+--------+
# |store_services   |2022_yoy_change|store_ct|
# +-----------------+---------------+--------+
# |In-Store Shopping|-0.0516        |632     |
# +-----------------+---------------+--------+
#
# +--------------+---------------+--------+
# |store_services|2022_yoy_change|store_ct|
# +--------------+---------------+--------+
# |Next Gen      |-0.0556        |33      |
# |No Next Gen   |-0.0514        |599     |
# +--------------+---------------+--------+
#
# +------------------+---------------+--------+
# |store_services    |2022_yoy_change|store_ct|
# +------------------+---------------+--------+
# |No In-Store Pickup|-0.0527        |33      |
# |In-Store Pickup   |-0.0516        |599     |
# +------------------+---------------+--------+
#
# +------------------+---------------+--------+
# |store_services    |2022_yoy_change|store_ct|
# +------------------+---------------+--------+
# |No Curbside Pickup|-0.0782        |45      |
# |Curbside Pickup   |-0.0494        |587     |
# +------------------+---------------+--------+
#
# +---------------------------------+---------------+--------+
# |store_services                   |2022_yoy_change|store_ct|
# +---------------------------------+---------------+--------+
# |No Scheduled or Same Day Delivery|-0.0873        |46      |
# |Scheduled or Same Day Delivery   |-0.048         |586     |
# +---------------------------------+---------------+--------+
#
# +-------------------+---------------+--------+
# |store_services     |2022_yoy_change|store_ct|
# +-------------------+---------------+--------+
# |Balloon Delivery   |-0.0518        |587     |
# |No Balloon Delivery|-0.0501        |45      |
# +-------------------+---------------+--------+
#
# +--------------+---------------+--------+
# |store_services|2022_yoy_change|store_ct|
# +--------------+---------------+--------+
# |No Helium     |-0.4317        |4       |
# |Helium        |-0.0459        |628     |
# +--------------+---------------+--------+

# %%
# best performing store's services

store_sales_agg = (
    store_sales
    .where(F.col('period_start') >= '2021-01-01')
    .groupBy('locationid')
    .agg(
        F.sum(F.when((F.col('period_start') >= '2021-01-01') 
               & (F.col('period_start') < '2022-01-01'), F.col('amount') ).otherwise(0)).alias('2021_spend'),
        F.sum(F.when((F.col('period_start') >= '2022-01-01') 
               & (F.col('period_start') < '2023-01-01'), F.col('amount') ).otherwise(0)).alias('2022_spend')
    
    )
    .withColumn('yoy',(F.col('2022_spend') - F.col('2021_spend'))/F.col('2021_spend'))

)

(
store_info
 .withColumn('locationid', F.col('location_id'))
 .join(store_sales_agg, 'locationid', 'inner')
    .orderBy(F.col('yoy').desc())
.select('state', 'store_services', 'yoy')
 .show(50, truncate = False)
)
# Out:
# +-------------+-----------------------------------------------------------------------------------------------------------------------------------------------+------------------+
# |state        |store_services                                                                                                                                 |yoy               |
# +-------------+-----------------------------------------------------------------------------------------------------------------------------------------------+------------------+
# |Mississippi  |In-Store Shopping | Helium                                                                                                                     |19.149014757508375|
# |Mississippi  |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Helium                                                |16.933944281408696|
# |Texas        |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |11.23135380923542 |
# |Mississippi  |In-Store Shopping | Helium                                                                                                                     |7.5866402259216   |
# |Tennessee    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Helium                                                                                 |5.5472797921458445|
# |Missouri     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |3.08315409754339  |
# |Massachusetts|In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |2.773078909192546 |
# |Missouri     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |2.509778221248215 |
# |Louisiana    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |2.436454466023999 |
# |Florida      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |2.4253595473092275|
# |Louisiana    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |2.1031664009616398|
# |Wisconsin    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.9816566389506223|
# |Tennessee    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Helium                                                                                 |1.8856525305525278|
# |Wisconsin    |In-Store Shopping | Helium                                                                                                                     |1.8390663830674523|
# |Massachusetts|In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.7447069826535462|
# |Wisconsin    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.7329998924002457|
# |Maryland     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.6634942546899742|
# |Florida      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.5723632365688287|
# |Wisconsin    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.5666757935062638|
# |Wisconsin    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.5494585691702727|
# |Connecticut  |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|1.4435310790288884|
# |Massachusetts|In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.4000937465958818|
# |Missouri     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.3905645079146605|
# |Delaware     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.3866624757623722|
# |Massachusetts|In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.3830961833194104|
# |Wisconsin    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.3745151955135617|
# |Alabama      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.3666754663693477|
# |Iowa         |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.350961862479672 |
# |Michigan     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.341885311358831 |
# |Wisconsin    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.3379130536904664|
# |Massachusetts|In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.336813158321883 |
# |Wisconsin    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.3105051306480038|
# |Texas        |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.2283283182348677|
# |Illinois     |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|1.2007944540938114|
# |California   |Flag Ship Store | In-Store Shopping | Next Gen | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium|1.1972838587920696|
# |Connecticut  |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.1430168120191075|
# |Louisiana    |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.1191262957813162|
# |Arizona      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.1098658827683094|
# |Indiana      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.1048894588158806|
# |Pennsylvania |In-Store Shopping | Helium                                                                                                                     |1.0465217627265424|
# |New York     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.0325423216357466|
# |Texas        |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.023306049961793 |
# |Pennsylvania |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |1.0059180633539504|
# |Alabama      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |0.9584660921442469|
# |Texas        |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |0.9510955462922202|
# |Michigan     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |0.9446253203273843|
# |Texas        |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |0.938630368963861 |
# |Florida      |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |0.9285099866012573|
# |Massachusetts|In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |0.9278913218666721|
# |Illinois     |In-Store Shopping | In-Store Pickup | Curbside Pickup | Scheduled or Same Day Delivery | Balloon Delivery | Helium                             |0.9259813974502105|
# +-------------+-----------------------------------------------------------------------------------------------------------------------------------------------+------------------+
# only showing top 50 rows

# %%
store_sales.where(F.col('locationid') == '1020').show()
# Out:
# +----------+------------+----------+-----+------+------+
# |locationid|period_start|period_end|label|amount|qt_end|
# +----------+------------+----------+-----+------+------+
# +----------+------------+----------+-----+------+------+

# %%
# I believe this the online store
store_open_close.where(F.col('locationid') == '1002').show()
# Out:
# +----------+-------------------+-------------------+
# |locationid|      est_open_date|     est_close_date|
# +----------+-------------------+-------------------+
# |      1002|2018-07-01 00:00:00|2024-09-01 00:00:00|
# +----------+-------------------+-------------------+

# %%
# every store has a close and end date
store_sales.select('locationid').distinct().join(store_open_close, 'locationid', 'left').where(F.col('est_open_date').isNull()).show()
# Out:
# +----------+-------------+--------------+
# |locationid|est_open_date|est_close_date|
# +----------+-------------+--------------+
# +----------+-------------+--------------+

# %%
# any non US stores? nope

states = [
    "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado",
    "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Idaho",
    "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana",
    "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota",
    "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire",
    "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota",
    "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina",
    "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia",
    "Washington", "West Virginia", "Wisconsin", "Wyoming"
]

store_info.where(~F.col('state').isin(states)).show()
# Out:
# +--------------------+----------+--------------------+--------------+-----------+-----------+--------------------+--------------------+--------------------+-------+--------+----------+------------------+
# |             address|as_of_date|                city|         phone|      state|location_id|      store_services|               title|                 url|zipcode|postcode|  latitude|         longitude|
# +--------------------+----------+--------------------+--------------+-----------+-----------+--------------------+--------------------+--------------------+-------+--------+----------+------------------+
# |22 González Guist...|2024-10-07|            Guaynabo|(787) 781-3605|Puerto Rico|         49|In-Store Shopping...|San Patricio Village|https://stores.pa...|    968|     968| 18.406803|       -66.1053842|
# |  RD #2, Bldg #2-828|2024-10-07|Bldg #2-828, Maya...|(787) 831-5121|Puerto Rico|        138|In-Store Shopping...|Villa Capitán Bld...|https://stores.pa...|    680|     680| 18.200345|       -67.1179511|
# |      15 Ave Comerío|2024-10-07|             Bayamon|(787) 269-4949|Puerto Rico|        141|In-Store Shopping...|Plaza del Parque ...|https://stores.pa...|    961|     961|18.4175898|       -66.1632846|
# |200 Rafael Corder...|2024-10-07|              Caguas|(787) 703-0720|Puerto Rico|        253|In-Store Shopping...|Plaza Centro Mall II|https://stores.pa...|    725|     725|18.2348356|-66.03038719999999|
# |KM 11.7 Barrio Ca...|2024-10-07|            Carolina|(787) 257-5770|Puerto Rico|        167|In-Store Shopping...|Los Colobos Shopp...|https://stores.pa...|    985|     985|18.3546093|-65.92444069999999|
# +--------------------+----------+--------------------+--------------+-----------+-----------+--------------------+--------------------+--------------------+-------+--------+----------+------------------+

# %%
# looking at some timeseries going downwards 
store_sales.groupBy('period_start','period_end','label').agg(F.count('*')).where(F.col('period_start') >= '2022-01-01').orderBy('period_start').show(300)
# Out:
# +------------+----------+---------+--------+
# |period_start|period_end|    label|count(1)|
# +------------+----------+---------+--------+
# |  2022-01-01|2022-01-31|2022-MS01|     744|
# |  2022-02-01|2022-02-28|2022-MS02|     756|
# |  2022-03-01|2022-03-31|2022-MS03|     764|
# |  2022-04-01|2022-04-30|2022-MS04|     761|
# |  2022-05-01|2022-05-31|2022-MS05|     762|
# |  2022-06-01|2022-06-30|2022-MS06|     763|
# |  2022-07-01|2022-07-31|2022-MS07|     762|
# |  2022-08-01|2022-08-31|2022-MS08|     767|
# |  2022-09-01|2022-09-30|2022-MS09|     769|
# |  2022-10-01|2022-10-31|2022-MS10|     800|
# |  2022-11-01|2022-11-30|2022-MS11|     738|
# |  2022-12-01|2022-12-31|2022-MS12|     759|
# |  2023-01-01|2023-01-31|2023-MS01|     720|
# |  2023-02-01|2023-02-28|2023-MS02|     748|
# |  2023-03-01|2023-03-31|2023-MS03|     739|
# |  2023-04-01|2023-04-30|2023-MS04|     733|
# |  2023-05-01|2023-05-31|2023-MS05|     729|
# |  2023-06-01|2023-06-30|2023-MS06|     715|
# |  2023-07-01|2023-07-31|2023-MS07|     699|
# |  2023-08-01|2023-08-31|2023-MS08|     692|
# |  2023-09-01|2023-09-30|2023-MS09|     695|
# |2022-09-30| 4146296.521482139|     798|
# |2022-12-31| 5927458.843006935|     794|
# |2023-03-31|4066617.2181202797|     774|
# |2023-06-30|4077826.9274084843|     766|
# |2023-09-30| 3432942.175473987|     735|
# |2023-12-31| 4686094.578831631|     744|
# +----------+------------------+--------+

# %%
# comp store calculations

store_sales_w_fp=(
    store_sales
    .where(F.col('qt_end')>= '2019-12-31')
     .groupBy('qt_end','locationid')
 .agg(F.sum('amount').alias('amount'))
 .join(store_open_close, 'locationid', 'left' )
)

comp_yoy = (store_sales_w_fp.alias('current')
    .where(# need 13 months to count as a comp
        (F.add_months(F.col('current.est_open_date'),13) <= F.col('current.qt_end'))
    )
     .join(store_sales_w_fp.alias('ly'), 
           # join exactly a year ago and by store
           (F.add_months(F.col('ly.qt_end'),12) == F.col('current.qt_end')) & 
           (F.col('ly.locationid') == F.col('current.locationid')) 
           ,
           'inner')
    .select('current.*', F.col('ly.amount').alias('ly_amount'), F.col('ly.qt_end').alias('ly_qt_end'))
      .groupBy('qt_end')
          .agg(
              F.sum('amount').alias('ty_amount'), 
              F.sum('ly_amount').alias('ly_amount'),
              F.count_distinct('locationid').alias('store_ct'),
               
                )
     .withColumn('yoy_change',(F.col('ty_amount')-F.col('ly_amount'))/F.col('ly_amount'))
    .orderBy('qt_end')
)

comp_yoy.show(100)
# Out:
# +----------+------------------+------------------+--------+--------------------+
# |    qt_end|         ty_amount|         ly_amount|store_ct|          yoy_change|
# +----------+------------------+------------------+--------+--------------------+
# |2020-12-31| 5547010.950353009| 5861563.863975732|     752|-0.05366365033671589|
# |2021-03-31|   3731197.5049473|2890111.5831117462|     740|  0.2910219545675698|
# |2021-06-30| 5009076.694535113|2235273.6773891114|     721|  1.2409232234980345|
# |2021-09-30| 4446626.898198184| 4063062.204639172|     750| 0.09440286026658916|
# |2021-12-31| 6330074.937772987| 5466850.967281493|     743| 0.15790150045388018|
# |2022-03-31| 3846958.901788982| 3702896.631956586|     744|0.038905290682196114|
# |2022-06-30|4546657.4958752105| 5046201.573961108|     754|-0.09899407916314593|
# |2022-09-30|  3887253.16254667|4445384.2333673835|     760|-0.12555294245013518|
# |2022-12-31| 5527187.867566972| 6312042.202794009|     753|-0.12434237763486802|
# |2023-03-31| 3825933.233048999|3800052.7090215324|     734|0.006810569749736...|
# |2023-06-30|3942819.3150014877| 4487606.175390588|     745|-0.12139809936456461|
# |2023-09-30| 3427851.059043393|3922157.0000958703|     727|-0.12602910618835372|
# |2023-12-31|4682220.3524946375| 5734625.547285317|     733|-0.18351768325812873|
# +----------+------------------+------------------+--------+--------------------+

# %%
comp_yoy.toPandas().to_csv('comp_yoy.csv')

# %%
# simple yoy calculations

w = Window.partitionBy(F.lit('')).orderBy("qt_end")
last_year_amount = F.lag(F.col("amount"), 4).over(w)
quarterly_sales = (
    store_sales
    .where(F.col('qt_end')>= '2019-12-31')
     .groupBy('qt_end')
     .agg(F.sum('amount').alias('amount'),F.count_distinct('locationid').alias('store_ct'))
     .withColumn('yoy', last_year_amount)
     .withColumn('yoy_change',(F.col('amount') - last_year_amount) / last_year_amount)
     .orderBy('qt_end')
)

quarterly_sales.show(20)
# Out:
# +----------+------------------+--------+------------------+--------------------+
# |    qt_end|            amount|store_ct|               yoy|          yoy_change|
# +----------+------------------+--------+------------------+--------------------+
# |2019-12-31| 5968705.615264985|     779|              NULL|                NULL|
# |2020-03-31|2934950.1018679305|     770|              NULL|                NULL|
# |2020-06-30|2276428.8576691262|     741|              NULL|                NULL|
# |2020-09-30|4115140.8896111823|     774|              NULL|                NULL|
# |2020-12-31| 5567378.338841764|     766| 5968705.615264985| -0.0672385777239247|
# |2021-03-31|3753022.1131896004|     761|2934950.1018679305| 0.27873455524883134|
# |2021-06-30| 5115723.719401804|     779|2276428.8576691262|  1.2472583327905442|
# |2021-09-30| 4496018.231040375|     780|4115140.8896111823| 0.09255511576547264|
# |2021-12-31| 6414808.341609914|     773| 5567378.338841764|  0.1522134748515131|
# |2022-03-31| 3892243.701251664|     771|3753022.1131896004|0.037095861378696436|
# |2022-06-30|4673587.1481143795|     796| 5115723.719401804|  -0.086426983851881|
# |2022-09-30| 4146296.521482139|     798| 4496018.231040375|-0.07778476233565251|
# |2022-12-31| 5927458.843006935|     794| 6414808.341609914|-0.07597257355948839|
# |2023-03-31|4066617.2181202797|     774| 3892243.701251664|  0.0448002566777976|
# |2023-06-30|4077826.9274084843|     766|4673587.1481143795| -0.1274738657534743|
# |2023-09-30| 3432942.175473987|     735| 4146296.521482139|-0.17204614824632838|
# |2023-12-31| 4686094.578831631|     744| 5927458.843006935|-0.20942604530098663|
# +----------+------------------+--------+------------------+--------------------+

# %%
quarterly_sales.toPandas().to_csv('quarterly_sales.csv')

# %%
# monthly calculations

w = Window.partitionBy(F.lit('')).orderBy("period_start")
last_year_amount = F.lag(F.col("amount"), 12).over(w)
monthly_sales = (
    store_sales
    .where(F.col('period_start')>= '2019-12-31')
    .groupBy('period_start')
     .agg(F.sum('amount').alias('amount'),F.count_distinct('locationid').alias('store_ct'))
     .withColumn('yoy', last_year_amount)
     .withColumn('yoy_change',(F.col('amount') - last_year_amount) / last_year_amount)
     .orderBy('period_start')
)

monthly_sales.show(300)
# Out:
# [Stage 926:>                                                        (0 + 1) / 1]
# +------------+------------------+--------+------------------+--------------------+
# |period_start|            amount|store_ct|               yoy|          yoy_change|
# +------------+------------------+--------+------------------+--------------------+
# |  2020-01-01|1104449.4093486872|     738|              NULL|                NULL|
# |  2020-02-01| 1126917.447651824|     754|              NULL|                NULL|
# |  2020-03-01| 703583.2448674168|     706|              NULL|                NULL|
# |  2020-04-01|144698.39209704567|      68|              NULL|                NULL|
# |  2020-05-01| 742517.5725841038|     505|              NULL|                NULL|
# |  2020-06-01|1389212.8929879726|     734|              NULL|                NULL|
# |  2020-07-01|1353286.8233231446|     730|              NULL|                NULL|
# |  2020-08-01|1349112.9344967334|     736|              NULL|                NULL|
# |  2020-09-01|1412741.1317913022|     728|              NULL|                NULL|
# |  2020-10-01|3113770.0965225394|     752|              NULL|                NULL|
# |  2020-11-01|1274535.7593584529|     734|              NULL|                NULL|
# |  2020-12-01|1179072.4829607797|     736|              NULL|                NULL|
